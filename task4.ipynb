# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img =cv2.imread("C:\\Users\\aedpu\\3 Rd year\\istockphoto-465407093-612x612.jpg")

# %%
img
# Out:
# array([[[56, 41, 32],
#         [56, 41, 32],
#         [56, 41, 32],
#         ...,
#         [58, 43, 34],
#         [58, 43, 34],
#         [58, 43, 34]],
#
#        [[56, 41, 32],
#         [56, 41, 32],
#         [56, 41, 32],
#         ...,
#         [58, 43, 34],
#         [58, 43, 34],
#         [58, 43, 34]],
#
#        [[56, 41, 32],
#         [56, 41, 32],
#         [56, 41, 32],
#         ...,
#         [58, 43, 34],
#         [58, 43, 34],
#         [58, 43, 34]],
#
#        ...,
#
#        [[59, 44, 35],
#         [58, 43, 34],
#         [57, 42, 33],
#         ...,
#         [60, 43, 34],
#         [60, 43, 34],
#         [60, 43, 34]],
#
#        [[59, 44, 35],
#         [58, 43, 34],
#         [57, 42, 33],
#         ...,
#         [60, 43, 34],
#         [60, 43, 34],
#         [60, 43, 34]],
#
#        [[59, 44, 35],
#         [58, 43, 34],
#         [57, 42, 33],
#         ...,
#         [61, 44, 35],
#         [61, 44, 35],
#         [61, 44, 35]]], dtype=uint8)

# %%
img=cv2.cvtColor(img,cv2.COLOR_RGB2BGR)

# %%
plt.imshow(img)

# %%
sobelX = cv2.Sobel(img,cv2.CV_64F,1,0)
sobelY = cv2.Sobel(img,cv2.CV_64F,0,1)

# %%
sobelX = np.uint8(np.absolute(sobelX))
sobelY = np.uint8(np.absolute(sobelY))

# %%
combind = cv2.bitwise_or(sobelX,sobelY)

# %%
plt.imshow(sobelY)

# %%
lab = cv2.Laplacian(img,cv2.CV_64F,ksize=3)
lab = np.uint(np.absolute(lab))

# %%
plt.imshow(sobelX)

# %%
combined_edges = cv2.addWeighted(sobelX,0.5,sobelY,0.5,0)

# %%
titles = ['image','sobleX','sobelY','combined','Laplacation']
images = [img,sobelX,sobelY,combind,lab]

for i in range(5):
    plt.subplot(2,3,i+1),plt.imshow(images[i])
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0..644].

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
view = cv2.VideoCapture("C:\\Users\\aedpu\\3 Rd year\\istockphoto-473394421-640_adpp_is.mp4",0)

# %%
print(view.isOpened())
# Out:
# True

# %%
while(view.isOpened()):
    ret, frame = view.read()
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    sobelX = cv2.Sobel(gray,cv2.CV_64F,1,0)
    sobelY = cv2.Sobel(gray,cv2.CV_64F,0,1)
    sobelX = np.uint8(np.absolute(sobelX))
    sobelY = np.uint8(np.absolute(sobelY))
    combind = cv2.bitwise_or(sobelX,sobelY)
    lab = cv2.Laplacian(img, cv2.CV_64F,ksize=3)
    lab = np.uint8(np.absolute(lab))
    cv2.imshow('Grey' ,gray)
    cv2.imshow('sobelX',sobelX)
    cv2.imshow('sobelY',sobelY)
    cv2.imshow('combind',combind)
    if cv2.waitKey(30) & 0xFF == ord('q'):
        break
                
view.release() 
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[20], line 3
#       1 while(view.isOpened()):
#       2     ret, frame = view.read()
# ----> 3     gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
#       4     sobelX = cv2.Sobel(gray,cv2.CV_64F,1,0)
#       5     sobelY = cv2.Sobel(gray,cv2.CV_64F,0,1)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
